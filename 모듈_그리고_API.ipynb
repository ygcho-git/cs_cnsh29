# %% [markdown]
# ### 방정식 풀이 모듈 : sympy

# %%
from sympy import Symbol, solve

x = Symbol('x')
equation = 2 * x - 6

r = solve(equation)

print(r)

# %%
from sympy import Symbol, solve

equation = x ** 2 + 3 * x + 2

r = solve(equation, dict=True) #dict 타입으로

print(r)

# %%
from sympy import Symbol, solve

equation = x ** 2 + x + 1

r = solve(equation, dict=True)

print(r)      # 허수는 I로...

# %%
# 연립 방정식 풀이

from sympy import Symbol, solve

y = Symbol('y')
equation1 = x + 2 * y - 3
equation2 = 3 * x - y + 2
solve((equation1, equation2), dict=True)

# %% [markdown]
# ## 인공지능 맛보기

# %% [markdown]
# ### 해양 쓰레기 분류 AI 만들어 보기
#
# https://studio.code.org/s/oceans/lessons/1/levels/2

# %% [markdown]
# ### keras에서 제공하는 pretrained 모델
# https://keras.io/api/applications/
#
# ### imagenet 분류 class
# ImageNet은 2009년에 만들어진 라벨이 지정된 이미지의 대규모 데이터 세트입니다. 20,000개 이상의 카테고리에 속하는 1,400만 개 이상의 이미지가 포함되어 있으며, 이는 동종 데이터 세트 중 가장 큰 규모입니다. ImageNet의 목표는 이미지 인식 알고리즘을 평가하고 컴퓨터 비전 분야를 발전시키기 위한 표준화된 벤치마크를 제공하는 것입니다.
#
#
# https://deeplearning.cms.waikato.ac.nz/user-guide/class-maps/IMAGENET/
# ![image.png](data:image/png;base64,...)

# %%
# 이미지 다운로드 받기

# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/chicken.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/ram.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/elephant.jpg'

# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/갈치구이01.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/갈치구이02.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/고등어구이01.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/고등어구이02.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/조기구이01.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/조기구이02.jpg'

# %%
# 이미 학습된 resnet50 모델 가져와서 분류해 보기
# https://keras.io/api/applications/

# %%
# preds 출력

print(preds)

# %% [markdown]
# ### 갈치구이, 고등어구이, 조기구이 분류 모델 만들어 보기
# https://teachablemachine.withgoogle.com/train/image

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 훈련용 이미지 다운로드 하기(갈치구이, 고등어구이, 조기구이)

# https://github.com/ygcho-git/basic_AI_2024/blob/main/data/갈치구이.zip

# https://github.com/ygcho-git/basic_AI_2024/blob/main/data/고등어구이.zip

# https://github.com/ygcho-git/basic_AI_2024/blob/main/data/조기구이.zip

# %%
# 모델을 코랩으로 가져오기
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/fish_model/keras_model.h5'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/fish_model/labels.txt'

# 평가를 위한 이미지 가져오기
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/갈치구이01.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/갈치구이02.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/고등어구이01.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/고등어구이02.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/조기구이01.jpg'
# !wget -q 'https://github.com/ygcho-git/basic_AI_2024/raw/main/data/조기구이02.jpg'

# %%
# 티처블 머신으로 학습시킨 모델(.h5)을 불러오기

from keras.models import load_model  # TensorFlow is required for Keras to work
from PIL import Image, ImageOps  # Install pillow instead of PIL
import numpy as np

# Disable scientific notation for clarity
np.set_printoptions(suppress=True)

# Load the model
model = load_model("keras_Model.h5", compile=False)

# Load the labels
class_names = open("labels.txt", "r").readlines()

# Create the array of the right shape to feed into the keras model
# The 'length' or number of images you can put into the array is
# determined by the first position in the shape tuple, in this case 1
data = np.ndarray(shape=(1, 224, 224, 3), dtype=np.float32)

# Replace this with the path to your image
image = Image.open("<IMAGE_PATH>").convert("RGB")

# resizing the image to be at least 224x224 and then cropping from the center
size = (224, 224)
image = ImageOps.fit(image, size, Image.Resampling.LANCZOS)

# turn the image into a numpy array
image_array = np.asarray(image)

# Normalize the image
normalized_image_array = (image_array.astype(np.float32) / 127.5) - 1

# Load the image into the array
data[0] = normalized_image_array

# Predicts the model
prediction = model.predict(data)
index = np.argmax(prediction)
class_name = class_names[index]
confidence_score = prediction[0][index]

# Print prediction and confidence score
print("Class:", class_name[2:], end="")
print("Confidence Score:", confidence_score)

# %% [markdown]
# ### chatgpt 모듈 활용해 보기

# %%
# gpt와 대화를 주고받을 수 있는 모듈 설치하기

pip install openai

# %%
import openai

my_chat = openai.OpenAI(api_key = "sk-proj-OypQboiQ2nG0ygI9ITZdT3BlbkFJjIYKqpEqW89CtAqT2pRb")

response = my_chat.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[{"role": "user", "content": "코믹 영화 추천해 줘."}],
  max_tokens=100
)

# %%
response

# %% [markdown]
# ```
# ChatCompletion(
#     id='chatcmpl-9Tjrb3M7ktlN2l6AJV3z41TwQAbT5',
#     choices=[
#         Choice(finish_reason='length', index=0, logprobs=None,
#             message=ChatCompletionMessage(
#                content='제가 여러분이 즐기실 수 있는 몇 가지 코믹 영화를 추천해 드리겠습니다.\n\n1. "Deadpool" (2016) - 라이언 레이놀즈 주연으로, 유머와 액션을 섞은 대담한 슈퍼히어로 영화입니다.\n\n2',
#                role='assistant',
#                function_call=None,
#                tool_calls=None)
#         )
#     ],
#     created=1716874839,
#     model='gpt-3.5-turbo-0125',
#     object='chat.completion',
#     system_fingerprint=None,
#     usage=CompletionUsage(completion_tokens=100, prompt_tokens=21, total_tokens=121)
# )
# ```

# %%
response.choices[0].message.content
# Out:
# '안녕하세요! 무엇을 도와드릴까요?'

# %% [markdown]
# ### Stable Diffusion 모델 써보기
#
# https://huggingface.co/stabilityai/stable-diffusion-2-1
